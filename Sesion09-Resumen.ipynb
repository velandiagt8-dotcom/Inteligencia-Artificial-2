# %% [markdown]
# <a href="https://colab.research.google.com/github/kathjeonbt-sys/Inteligencia-Artificial-II/blob/main/Sesion09-Resumen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Resumen Sesion 9**
#
# La clasificación y diagnóstico en Machine Learning permite evaluar qué tan bien funciona un algoritmo. MNIST es un conjunto de datos usado para reconocer números escritos a mano. La clasificación binaria trabaja con dos posibles resultados, mientras que la matriz de confusión ayuda a identificar los aciertos y errores. La precisión y exhaustividad muestran qué tan bien identifica los casos, y la clasificación multiclase permite trabajar con varias categorías.
