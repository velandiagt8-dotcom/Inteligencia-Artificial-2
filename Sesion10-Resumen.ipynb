# %% [markdown]
# <a href="https://colab.research.google.com/github/kathjeonbt-sys/Inteligencia-Artificial-II/blob/main/Sesion10-Resumen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Resumen Sesion 10**
#
# El descenso de gradiente usa derivadas para reducir el error de un modelo hasta encontrar el mejor resultado. Puede trabajar por lotes, mini lotes o de forma estocástica, usando todos los datos, grupos pequeños o datos al azar. La velocidad de aprendizaje y su cronograma controlan qué tan rápido aprende el modelo.
#
# La regresión polinomial adapta un modelo lineal para trabajar con datos complejos y curvas. Las curvas de aprendizaje permiten observar el ajuste del modelo y detectar problemas como el sobreajuste o la diferencia entre entrenamiento y prueba. La regresión logística permite clasificar y predecir probabilidades.
